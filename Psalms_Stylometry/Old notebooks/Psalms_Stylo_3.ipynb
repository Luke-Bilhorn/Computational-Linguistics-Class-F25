# %%
import rpy2.robjects as ro
R = ro.r
R.library("stylo")
# The next line makes your home folder the "working directory" where anything running in
# R will write out results. Change this to another folder if you don't want stuff written in
# your home folder.
R.setwd("~/CSCI384/Psalms_Stylometry")

# %%
R.classify(**{'training.corpus.dir':'/homes/lukebilhorn/CSCI384/Psalms_Stylometry/corpus/primary_set', 'test.corpus.dir':'/homes/lukebilhorn/CSCI384/Psalms_Stylometry/corpus/secondary_set','gui':True})

# %%
R.stylo(**{'corpus.dir':'/homes/tvandrun/Public/cs384/stylo/alcottwilder1/corpus', 'gui':True})
# Out:
# R[write to console]: using current directory...
#
# R[write to console]: Performing no sampling (using entire text as sample)
#
#
# R[write to console]: slicing input text into tokens...
#
#
# R[write to console]:
# turning words into features, e.g. char n-grams (if applicable)...
#
# R[write to console]:
#
# R[write to console]: Total nr. of samples in the corpus: 12
#
# R[write to console]:
#
# R[write to console]: The corpus consists of 4690350 tokens
#
# R[write to console]:
#
# R[write to console]: processing  12  text samples
#
# R[write to console]: .
# R[write to console]:
#
# R[write to console]: combining frequencies into a table...
#
# R[write to console]:
#
#
# R[write to console]: culling @ 0	available features (words) 31
#
# R[write to console]: Calculating z-scores...
#
#
# R[write to console]: Calculating classic Delta distances...
#
# R[write to console]: MFW used:
#
# R[write to console]: 31
# R[write to console]:
#
# R[write to console]: using current directory...
